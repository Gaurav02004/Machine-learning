# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# <StringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df[df['species'] == 'setosa']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].map({'versicolor':0,'virginica':1})
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 145    1.0
# 146    1.0
# 147    1.0
# 148    1.0
# 149    1.0
# Name: species, Length: 150, dtype: float64

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
## Split Dataset into a independent and dependent feature
x = df.iloc[:,:-1]
y = df.iloc[:,:-1]

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state = 42)

# %% [markdown]
# from sklearn.linear_model import LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'penalty':['11','12','elasticnet'],'c':[1,2,3,4,5,6,10,20,30,40,50],'max_iter':[100,200,300]}

# %%
classifier_regressor = GridSearchCV(classifier,param_grid = 'parameters',scoring = 'accuracy',cv=5)

# %%
print(classifier_regressor)
# Out:
# GridSearchCV(cv=5,
#              estimator=<class 'sklearn.linear_model._logistic.LogisticRegression'>,
#              param_grid='parameters', scoring='accuracy')

# %%
LogisticRegression(penalty='none')
# Out:
# LogisticRegression(penalty='none')

# %%
classifier_regressor.get_params()
# Out:
# {'cv': 5,
#  'error_score': nan,
#  'estimator': sklearn.linear_model._logistic.LogisticRegression,
#  'n_jobs': None,
#  'param_grid': 'parameters',
#  'pre_dispatch': '2*n_jobs',
#  'refit': True,
#  'return_train_score': False,
#  'scoring': 'accuracy',
#  'verbose': 0}

# %%
from sklearn.linear_model import LogisticRegression

classifier_regressor = LogisticRegression()

# %%
classifier_regressor.fit(x_train, y_train)

LogisticRegression(penalty='none')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 classifier_regressor.fit(x_train, y_train)
#       2
#       3 LogisticRegression(penalty='none')
#
# File C:\Python314\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File C:\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1459, in LogisticRegression.fit(self, X, y, sample_weight)
#    1456 if self.n_jobs is not None:
#    1457     warnings.warn(msg, category=FutureWarning)
# -> 1459 X, y = validate_data(
#    1460     self,
#    1461     X,
# ...

# %%
LogisticRegression(penalty=None)

# %%
from sklearn.linear_model import LogisticRegression

classifier_regressor = LogisticRegression(penalty=None)

classifier_regressor.fit(x_train, y_train)

# %%
print(x_train.shape)
print(y_train.shape)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(classifier_regressor.fit(x_train, y_train)
    x, y, test_size=0.2, random_state=42
)

# %%
print(x_train.shape)
print(y_train.shape)

# %%
classifier_regressor.fit(x_train, y_train)

# %%
print(classifier_regressor.best_params_)

# %%
print(classifier_regressor.best_score_)

# %%
## Prediction
y_pred = classifier_regressor.predict(x_test)

# %%
## Accuracy score
from sklearn.metrics import accuracy_score,classification_report

# %%
score = accuracy_score(y_pred,y_test)

# %%
print(score)

# %%
print(classification_report(y_pred,y_test))

# %%
sns.pairplot(df,hue = 'species')

# %%
df.corr()
