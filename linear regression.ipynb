# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Python314\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Python314\Lib\site-packages (from scikit-learn) (2.5.1)
# Requirement already satisfied: scipy>=1.10.0 in C:\Python314\Lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in C:\Python314\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Python314\Lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Python314\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.datasets import load_diabetes

data = load_diabetes()

print(data.data.shape)
print(data.target.shape)
# Out:
# (442, 10)
# (442,)

# %%
from sklearn.datasets import load_diabetes

data = load_diabetes()

print(data.data.shape)
print(data.target.shape)
# Out:
# (442, 10)
# (442,)

# %%
df = load_diabetes()
dataset = pd.DataFrame(df.data)

# %%
dataset
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#             7         8         9
# 0   -0.002592  0.019907 -0.017646
# 1   -0.039493 -0.068332 -0.092204
# 2   -0.002592  0.002861 -0.025930
# 3    0.034309  0.022688 -0.009362
# 4   -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064
#
# [442 rows x 10 columns]

# %%
dataset.columns = df.feature_names

# %%
dataset.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
# Independent features and dependent features
x = dataset
y = df.target
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#         60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#        197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#         59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#        237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#        143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#        142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#         77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#         78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#        154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#         71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#        150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#        145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#         94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#         60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#         31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#        114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#        191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#        244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#        263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#         77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#         58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#        140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#        219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#         43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#        140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#         84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#         94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#        220.,  57.])

# %%
#Train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = 42)
x_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 225  0.030811  0.050680  0.032595  0.049415 -0.040096 -0.043589 -0.069172
# 412  0.074401 -0.044642  0.085408  0.063187  0.014942  0.013091  0.015505
# 118 -0.056370  0.050680 -0.010517  0.025315  0.023198  0.040022 -0.039719
# 114  0.023546 -0.044642  0.110198  0.063187  0.013567 -0.032942 -0.024993
# 364  0.001751  0.050680 -0.006206 -0.019442 -0.009825  0.004949 -0.039719
# ..        ...       ...       ...       ...       ...       ...       ...
# 106 -0.096328 -0.044642 -0.076264 -0.043542 -0.045599 -0.034821  0.008142
# 270  0.005383  0.050680  0.030440  0.083844 -0.037344 -0.047347  0.015505
# 348  0.030811 -0.044642 -0.020218 -0.005670 -0.004321 -0.029497  0.078093
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 102 -0.092695 -0.044642  0.028284 -0.015999  0.036958  0.024991  0.056003
#
#            s4        s5        s6
# 225  0.034309  0.063015  0.003064
# 412 -0.002592  0.006207  0.085907
# 118  0.034309  0.020609  0.056912
# 114  0.020655  0.099241  0.023775
# 364  0.034309  0.014821  0.098333
# ..        ...       ...       ...
# 106 -0.039493 -0.059471 -0.083920
# 270 -0.039493  0.008641  0.015491
# 348 -0.039493 -0.010903 -0.001078
# 435 -0.002592 -0.038460 -0.038357
# 102 -0.039493 -0.005142 -0.001078
#
# [309 rows x 10 columns]

# %%
#Standardizing the dataset
from sklearn.preprocessing import StandardScaler
Scaler = StandardScaler()
x_train = Scaler.fit_transform(x_train)
x_test = Scaler.transform(x_test)

# %% [markdown]
# from sklearn.linear_model LinearRegression

# %%
# Cross Validation

from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

regression = LinearRegression()

regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
import numpy as np
mse = cross_val_score(regression,x_train,y_train,scoring = 'neg_mean_squared_error',cv = 10)
np.mean(mse)
# Out:
# np.float64(-3168.262316055522)

# %%
import numpy as np
mse = cross_val_score(regression,x_train,y_train,scoring = 'neg_mean_squared_error',cv = 10)
np.mean(mse)
# Out:
# np.float64(-3168.262316055522)

# %%
# Prediction

reg_pred = regression.predict(x_test)

print(reg_pred)

import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(reg_pred, kind='kde')

from sklearn.metrics import r2_score

score = r2_score(y_test, reg_pred)

print("R2 Score:", score)
# Out:
# [138.46970031 181.10052342 125.34400904 292.75977277 123.8830531
#   91.89830434 257.26463123 177.76169318  84.98549706 109.15960992
#   94.4855284  166.13235108  57.40742502 206.13897354  97.7811842
#  131.00472765 214.29789972 252.52907661 199.66656381 219.49985634
#  203.23671317  88.00656925  70.65108459 186.92233427 155.81266751
#  162.81022205 191.93135706 184.72924276  46.62920829 108.26566599
#  178.14743952  91.35065005 127.72125745 184.04205666 172.23799897
#  189.51548863 121.83265708 117.75339206 145.67950306  58.57563401
#   72.55421321 107.27571105 166.15280313 153.29339984 165.19282154
#   62.95752038  73.58909449 110.05656189  54.49723354 164.88920632
#  152.49472803  63.8874565  111.4354561  108.34936269 179.96973311
#  158.70054112  95.04833555 209.68990406 118.37356519  69.69946093
#  189.04680627 204.99138626 140.26840176 105.75963198 131.22316354
#  201.65649349 173.60251683 164.25810664 122.01567481 143.53425629
#  179.42286037 201.32086534 234.50804093 146.96093984  80.27567403
#  160.86822173 192.72110552 208.6585054  158.56823462 206.00933474
#  111.53729194 140.28763033  51.15323818  54.76434639 113.02207773
#   78.46425825  80.20416459  56.97774667 168.51207071 185.55749267
#  152.33436369 242.66080008 106.44250735  61.34968205  53.44975218
#  197.78538801 246.62420102 185.25237675 105.80114548  62.42547543
#  193.39002547 107.08821595 297.08578592  94.45306615 148.41869832
#  104.10666888 128.66940497 126.90012169 165.84858396 186.14546255
#  108.5888133  203.83170771 204.97622269 209.10156998 191.65509488
#  161.26918179 148.51075431 135.0455994  111.74197539 163.62966339
#  170.55301782  95.53608319  46.85961143 164.34533761 127.1747026
#  176.61035076 173.47305611 107.40153597 202.99778708  92.10100436
#  122.28876806  80.80866991 233.21870492]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 7
#       3 reg_pred = regression.predict(x_test)
#       4
#       5 print(reg_pred)
#       6
# ----> 7 import seaborn as sns
#       8 import matplotlib.pyplot as plt
#       9
#      10 sns.displot(reg_pred, kind='kde')
#
# ModuleNotFoundError: No module named 'seaborn'
